# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
city_data = ("/Users/bigd/Downloads/201908-citibike-tripdata.csv")
city_data_df = pd.read_csv(city_data)

# %%
city_data_df.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0           393   00:01.5  06:35.4             531.0
# 1           627   00:01.9  10:29.8             274.0
# 2          1132   00:04.0  18:56.2            2000.0
# 3          1780   00:04.2  29:44.8             479.0
# 4          1517   00:05.5  25:23.5            3312.0
#
#                start station name  start station latitude  \
# 0          Forsyth St & Broome St               40.718939
# 1  Lafayette Ave & Fort Greene Pl               40.686919
# 2        Front St & Washington St               40.702551
# 3                 9 Ave & W 45 St               40.760193
# 4                 1 Ave & E 94 St               40.781721
#
#    start station longitude  end station id            end station name  \
# 0               -73.992663           408.0       Market St & Cherry St
# 1               -73.976682          3409.0        Bergen St & Smith St
# 2               -73.989402          3388.0     President St & Henry St
# ...

# %%
# 2. Check the datatypes of your columns. 
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripduration             1048575 non-null  int64
#  1   starttime                1048575 non-null  object
#  2   stoptime                 1048575 non-null  object
#  3   start station id         1048549 non-null  float64
#  4   start station name       1048549 non-null  object
#  5   start station latitude   1048575 non-null  float64
#  6   start station longitude  1048575 non-null  float64
#  7   end station id           1048549 non-null  float64
#  8   end station name         1048549 non-null  object
#  9   end station latitude     1048575 non-null  float64
#  10  end station longitude    1048575 non-null  float64
#  11  bikeid                   1048575 non-null  int64
#  12  usertype                 1048575 non-null  object
# ...

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
city_data_df['tripdur_orig'] = city_data_df['tripduration']
city_data_df['tripduration'] = pd.to_datetime(city_data_df['tripduration'], unit = 'm')

# %%
city_data_df.head()
# Out:
#          tripduration starttime stoptime  start station id  \
# 0 1970-01-01 06:33:00   00:01.5  06:35.4             531.0
# 1 1970-01-01 10:27:00   00:01.9  10:29.8             274.0
# 2 1970-01-01 18:52:00   00:04.0  18:56.2            2000.0
# 3 1970-01-02 05:40:00   00:04.2  29:44.8             479.0
# 4 1970-01-02 01:17:00   00:05.5  25:23.5            3312.0
#
#                start station name  start station latitude  \
# 0          Forsyth St & Broome St               40.718939
# 1  Lafayette Ave & Fort Greene Pl               40.686919
# 2        Front St & Washington St               40.702551
# 3                 9 Ave & W 45 St               40.760193
# 4                 1 Ave & E 94 St               40.781721
#
#    start station longitude  end station id            end station name  \
# 0               -73.992663           408.0       Market St & Cherry St
# 1               -73.976682          3409.0        Bergen St & Smith St
# ...

# %%
# 4. Check the datatypes of your columns. 
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripduration             1048575 non-null  datetime64[ns]
#  1   starttime                1048575 non-null  object
#  2   stoptime                 1048575 non-null  object
#  3   start station id         1048549 non-null  float64
#  4   start station name       1048549 non-null  object
#  5   start station latitude   1048575 non-null  float64
#  6   start station longitude  1048575 non-null  float64
#  7   end station id           1048549 non-null  float64
#  8   end station name         1048549 non-null  object
#  9   end station latitude     1048575 non-null  float64
#  10  end station longitude    1048575 non-null  float64
#  11  bikeid                   1048575 non-null  int64
#  12  usertype                 1048575 non-null  object
# ...

# %%
# 5. Export the Dataframe as a new CSV file without the index.
city_data_df.to_csv("/Users/bigd/Downloads/201908-citibike_updt.csv", index=False)
